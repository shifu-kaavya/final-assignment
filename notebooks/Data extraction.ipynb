# %%
import pandas as pd

# %%
# Load CSV files into DataFrames
dimCompany_df = pd.read_csv('dimCompany.csv')
dimCoin_df = pd.read_csv('dimCoin.csv')
factStocks_df = pd.read_csv('factStocks.csv')
dimTime_df = pd.read_csv('dimTime.csv')
factCoins_df = pd.read_csv('factCoins.csv')

# %%
# Display the first few rows of each DataFrame
print(dimCompany_df.head())
print(dimCoin_df.head())
print(factStocks_df.head())
print(dimTime_df.head())
print(factCoins_df.head())

# Get basic info about each DataFrame
print(dimCompany_df.info())
print(dimCoin_df.info())
print(factStocks_df.info())
print(dimTime_df.info())
print(factCoins_df.info())

# Generate summary statistics
print(dimCompany_df.describe())
print(dimCoin_df.describe())
print(factStocks_df.describe())
print(dimTime_df.describe())
print(factCoins_df.describe())
# Out:
#    keyCompany stockCodeCompany   nameCompany sectorCodeCompany  \
# 0           1            BRAP4     BRADESPAR              IMAT
# 1           2            PMAM3  PARANAPANEMA              IMAT
# 2           3            CSNA3  SID NACIONAL              IMAT
# 3           4            SUZB3   SUZANO S.A.              IMAT
# 4           5            BRKM5       BRASKEM              IMAT
#
#                               sectorCompany        segmentCompany
# 0  BM&FBOVESPA BASIC MATERIALS INDEX (IMAT)  SEGMENTS AND SECTORS
# 1  BM&FBOVESPA BASIC MATERIALS INDEX (IMAT)  SEGMENTS AND SECTORS
# 2  BM&FBOVESPA BASIC MATERIALS INDEX (IMAT)  SEGMENTS AND SECTORS
# 3  BM&FBOVESPA BASIC MATERIALS INDEX (IMAT)  SEGMENTS AND SECTORS
# 4  BM&FBOVESPA BASIC MATERIALS INDEX (IMAT)  SEGMENTS AND SECTORS
#    keyCoin abbrevCoin nameCoin symbolCoin
# 0        1        USD    DOLAR          $
# 1        2        EUR     EURO          €
# ...
